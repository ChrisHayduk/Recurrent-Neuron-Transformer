# %%
import torch
from torch import nn
from models.recurrent_neuron_transformer import RecurrentNeuronTransformer
from tqdm import tqdm
DEVICE = "cuda"

# %%
def train_shakespeare_transformer(model, context_window, step_size, data_loader, optimizer, num_epochs, device='cuda', mask=False):
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        progress_bar = tqdm(data_loader, desc=f'Epoch {epoch+1}/{num_epochs}', leave=False)

        for batch_idx, (input_chunk, target_chunk) in enumerate(progress_bar):
            # Initialize batch loss
            batch_loss = 0

            # Reset hidden layers at the start of each batch
            hidden_layers = dict()

            for i in range(0, input_chunk.size(1) - context_window, step_size):
                print(f"Chunk starting at position {i} in batch {batch_idx}")

                # Create input and target sequences
                input_seq = input_chunk[:, i:i+context_window].to(device)
                target_seq = target_chunk[:, i+1:i+context_window+1].to(device)

                # Forward pass
                optimizer.zero_grad()
                outputs, hidden_layers = model(inputs=input_seq, hidden_layers=hidden_layers)
                outputs = outputs.view(-1, outputs.size(-1))
                target_seq = target_seq.view(-1)

                # Calculate loss
                loss = nn.CrossEntropyLoss()(outputs, target_seq)
                loss.backward()  # Backpropagate on each loss
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()

                batch_loss += loss.item()  # Accumulate the scalar loss

            # Update running loss for the epoch
            epoch_loss += batch_loss

            # Update progress bar
            progress_bar.set_postfix(loss=epoch_loss / (batch_idx + 1))

        print(f"Epoch {epoch+1}/{num_epochs} completed. Average batch loss: {epoch_loss / len(data_loader)}")

# %%
from transformers import GPT2Tokenizer
from torch.utils.data import TensorDataset, DataLoader
import os
from utils.datasets import TextDataLoader

# Define tokenizer used to convert text to tokens
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

file_path = os.path.join(os.getcwd(), 'data', 'shakespeare', 'tinyshakespeare.txt')
bpe_tokenizer = 'gpt2'
seq_length = 256
batch_size = 10
vocab_size = 50257
data_loader = TextDataLoader(file_path, seq_length, bpe_tokenizer, batch_size, vocab_size)
train_loader, test_loader = data_loader.create_loaders()

# %%
# Define the context window size k (defaulting to chunk_length / 2)
context_window = 128

# Define the model
transformer_model = RecurrentNeuronTransformer(input_size=tokenizer.vocab_size, output_size=tokenizer.vocab_size, device=DEVICE, max_length=context_window)
transformer_model.to(DEVICE)
# Define optimizer
transformer_optimizer = torch.optim.Adam(transformer_model.parameters(), lr=0.001)

# %%
# Define the step size to use for the sliding window
step_size = 127

# Train the model
train_shakespeare_transformer(transformer_model, context_window, step_size, train_loader, 
                               optimizer=transformer_optimizer, num_epochs=2)
# Out:
# Epoch 1/2:   0%|          | 0/27016 [00:00<?, ?it/s]
# Chunk starting at position 0 in batch 0
# term2 NaN count: tensor(0, device='cuda:0')
# term2 tensor([[[0.0122,   -inf,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0209, 0.0119,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0135, 0.0129, 0.0200,  ...,   -inf,   -inf,   -inf],
#          ...,
#          [0.0094, 0.0092, 0.0176,  ..., 0.0101,   -inf,   -inf],
#          [0.0094, 0.0092, 0.0176,  ..., 0.0101, 0.0101,   -inf],
#          [0.0094, 0.0092, 0.0176,  ..., 0.0101, 0.0101, 0.0101]],
#
#         [[0.0091,   -inf,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0284, 0.0068,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0106, 0.0068, 0.0203,  ...,   -inf,   -inf,   -inf],
#          ...,
#          [0.0077, 0.0106, 0.0176,  ..., 0.0105,   -inf,   -inf],
#          [0.0077, 0.0106, 0.0176,  ..., 0.0105, 0.0105,   -inf],
#          [0.0077, 0.0106, 0.0176,  ..., 0.0105, 0.0105, 0.0105]],
#
#         [[0.0173,   -inf,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0173, 0.0143,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0180, 0.0087, 0.0178,  ...,   -inf,   -inf,   -inf],
#          ...,
#          [0.0103, 0.0174, 0.0107,  ..., 0.0106,   -inf,   -inf],
#          [0.0103, 0.0174, 0.0107,  ..., 0.0106, 0.0106,   -inf],
#          [0.0103, 0.0174, 0.0107,  ..., 0.0106, 0.0106, 0.0106]],
#
#         ...,
#
#         [[0.0137,   -inf,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0214, 0.0080,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0178, 0.0120, 0.0276,  ...,   -inf,   -inf,   -inf],
#          ...,
#          [0.0087, 0.0081, 0.0191,  ..., 0.0100,   -inf,   -inf],
#          [0.0087, 0.0081, 0.0191,  ..., 0.0100, 0.0100,   -inf],
#          [0.0087, 0.0081, 0.0191,  ..., 0.0100, 0.0100, 0.0100]],
#
#         [[0.0205,   -inf,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0104, 0.0148,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0137, 0.0082, 0.0133,  ...,   -inf,   -inf,   -inf],
#          ...,
#          [0.0120, 0.0136, 0.0115,  ..., 0.0102,   -inf,   -inf],
#          [0.0120, 0.0136, 0.0115,  ..., 0.0102, 0.0102,   -inf],
#          [0.0120, 0.0136, 0.0115,  ..., 0.0102, 0.0102, 0.0102]],
#
#         [[0.0071,   -inf,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0094, 0.0066,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.0070, 0.0114, 0.0138,  ...,   -inf,   -inf,   -inf],
#          ...,
#          [0.0061, 0.0102, 0.0153,  ..., 0.0101,   -inf,   -inf],
#          [0.0061, 0.0102, 0.0153,  ..., 0.0101, 0.0101,   -inf],
#          [0.0061, 0.0102, 0.0153,  ..., 0.0101, 0.0101, 0.0101]]],
#        device='cuda:0', grad_fn=<MaskedFillBackward0>)
# v2 NaN count: tensor(0, device='cuda:0')
# v2 tensor([[[0.2629, 0.3516, 0.3826,  ..., 0.0000, 0.7805, 0.0513],
#          [0.0000, 0.0000, 1.3092,  ..., 0.3110, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.3377, 0.0000, 1.0789],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.9508, 0.3958],
#          [0.5959, 0.5551, 0.9471,  ..., 0.3110, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 2.0549, 0.0000],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[0.0000, 0.0000, 0.7635,  ..., 0.0000, 0.6631, 0.8435],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.1169, 0.0000],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         ...,
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 1.4304],
#          [0.0000, 0.0000, 1.2175,  ..., 0.3110, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0179, 0.0000, 1.1621],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[0.0000, 0.0000, 1.0142,  ..., 0.0000, 1.5978, 0.5296],
#          [0.0000, 0.0000, 0.3497,  ..., 0.0208, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.4242, 0.8261, 0.2826],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 1.2533, 0.0000],
#          [0.0000, 0.0000, 0.0512,  ..., 0.0000, 0.1120, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.2105, 0.1514, 0.4620],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]]],
#        device='cuda:0', grad_fn=<ViewBackward0>)
# head2 NaN count: tensor(102720, device='cuda:0')
# head2 tensor([[[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.5007, 0.2290, 0.3002,  ..., 0.1273, 0.2810, 0.6894]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.5840, 0.2439, 0.2800,  ..., 0.1061, 0.2274, 0.7099]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.5407, 0.1885, 0.1976,  ..., 0.1176, 0.2427, 0.7361]],
#
#         ...,
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.5450, 0.3009, 0.3206,  ..., 0.1025, 0.2468, 0.7025]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.5018, 0.2317, 0.3107,  ..., 0.1105, 0.2513, 0.6870]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [  -inf,    nan,   -inf,  ...,   -inf,   -inf,   -inf],
#          [0.5484, 0.2598, 0.2551,  ..., 0.1062, 0.2560, 0.6877]]],
#        device='cuda:0', grad_fn=<BmmBackward0>)
# Chunk starting at position 127 in batch 0
# term2 NaN count: tensor(82560, device='cuda:0')
# term2 tensor([[[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<MaskedFillBackward0>)
# v2 NaN count: tensor(40960, device='cuda:0')
# v2 tensor([[[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         ...,
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]]],
#        device='cuda:0', grad_fn=<ViewBackward0>)
# head2 NaN count: tensor(122880, device='cuda:0')
# head2 tensor([[[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<BmmBackward0>)
# Epoch 1/2:   0%|          | 1/27016 [00:03<28:38:35,  3.82s/it, loss=nan]
# Chunk starting at position 0 in batch 1
# term2 NaN count: tensor(82560, device='cuda:0')
# term2 tensor([[[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<MaskedFillBackward0>)
# v2 NaN count: tensor(54620, device='cuda:0')
# v2 tensor([[[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         ...,
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]]],
#        device='cuda:0', grad_fn=<ViewBackward0>)
# head2 NaN count: tensor(122880, device='cuda:0')
# head2 tensor([[[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<BmmBackward0>)
# Chunk starting at position 127 in batch 1
# term2 NaN count: tensor(82560, device='cuda:0')
# term2 tensor([[[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<MaskedFillBackward0>)
# v2 NaN count: tensor(59170, device='cuda:0')
# v2 tensor([[[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         ...,
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]]],
#        device='cuda:0', grad_fn=<ViewBackward0>)
# head2 NaN count: tensor(122880, device='cuda:0')
# head2 tensor([[[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<BmmBackward0>)
# Epoch 1/2:   0%|          | 2/27016 [00:06<24:10:58,  3.22s/it, loss=nan]
# Chunk starting at position 0 in batch 2
# term2 NaN count: tensor(82560, device='cuda:0')
# term2 tensor([[[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<MaskedFillBackward0>)
# v2 NaN count: tensor(60690, device='cuda:0')
# v2 tensor([[[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         ...,
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]]],
#        device='cuda:0', grad_fn=<ViewBackward0>)
# head2 NaN count: tensor(122880, device='cuda:0')
# head2 tensor([[[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<BmmBackward0>)
# Chunk starting at position 127 in batch 2
# term2 NaN count: tensor(82560, device='cuda:0')
# term2 tensor([[[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, -inf, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, -inf,  ..., -inf, -inf, -inf],
#          [nan, nan, nan,  ..., -inf, -inf, -inf],
#          ...,
#          [nan, nan, nan,  ..., nan, -inf, -inf],
#          [nan, nan, nan,  ..., nan, nan, -inf],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<MaskedFillBackward0>)
# v2 NaN count: tensor(61190, device='cuda:0')
# v2 tensor([[[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         ...,
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]],
#
#         [[   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798],
#          [0.9829, 0.0000, 0.2625,  ..., 0.0321, 0.1073, 1.3798]]],
#        device='cuda:0', grad_fn=<ViewBackward0>)
# head2 NaN count: tensor(122880, device='cuda:0')
# head2 tensor([[[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0',
#        grad_fn=<BmmBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\chris\Desktop\recurrent_neuron_transformers\recurrent_neuron_transformer_testing.ipynb Cell 5 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> step_size = 127
#       <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> # Train the model
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> train_shakespeare_transformer(transformer_model, context_window, step_size, train_loader,
#       <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>                                optimizer=transformer_optimizer, num_epochs=2)
#
# c:\Users\chris\Desktop\recurrent_neuron_transformers\recurrent_neuron_transformer_testing.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=26'>27</a> # Calculate loss
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=27'>28</a> loss = nn.CrossEntropyLoss()(outputs, target_seq)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=28'>29</a> loss.backward()  # Backpropagate on each loss
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=29'>30</a> torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/recurrent_neuron_transformers/recurrent_neuron_transformer_testing.ipynb#X12sZmlsZQ%3D%3D?line=30'>31</a> optimizer.step()
#
# File c:\Python311\Lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File c:\Python311\Lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:
