# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf Recurrent-Neuron-Transformer

# %%
# !git clone -b add-dev-container-debug-and-run-name https://github.com/ChrisHayduk/Recurrent-Neuron-Transformer.git
# Out:
# Cloning into 'Recurrent-Neuron-Transformer'...
# remote: Enumerating objects: 696, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 696 (delta 185), reused 167 (delta 109), pack-reused 448
# Receiving objects: 100% (696/696), 27.81 MiB | 15.97 MiB/s, done.
# Resolving deltas: 100% (442/442), done.

# %%
# !cd Recurrent-Neuron-Transformer/ && pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 42.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 109.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 106.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 47.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 100.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 100.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 88.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 37.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.8 MB/s eta 0:00:00
# ...

# %%
# !cd Recurrent-Neuron-Transformer/ && python -m \
experiments.reconstruct_shakespeare --model_name=StatefulTransformer --data_path=data/shakespeare/tinyshakespeare.txt \
--num_epochs=1 --chunk_size=1024 --max_seq_length=512 --window_step_size=511 --num_layers=8 --nhead=8 --dmodel=768 --batch_size=6 --dropout=0.1 --lr=0.0005 --recurrent_layers="proj"
# Out:
# /content/Recurrent-Neuron-Transformer
# Using device: cuda
# RecurrentModelConfig(max_length=512, vocab_size=50304, n_layer=8, num_heads=8, hidden_dim=768, dropout=0.1, device=device(type='cuda'), recurrent_layers='proj')
# Number of parameters: 134.75M
# Training StatefulTransformer on data/shakespeare/tinyshakespeare.txt with chunk size 1024, context window size 512, and step size 511
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.16.1
# ...
